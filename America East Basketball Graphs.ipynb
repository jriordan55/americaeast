# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data for the america east conference
df = pd.read_csv("AETeam.csv")
df
# Out:
#    #           Team    TS%   eFG%  Total S%  ORB%  DRB%  TRB%  AST%  TOV%  \
# 0  8         Albany  0.514  0.481     142.8  30.2  71.3  49.2  51.2  17.5
# 1  7     Binghamton  0.524  0.493     142.2  31.2  71.9  51.7  44.8  17.8
# 2  2         Bryant  0.575  0.544     156.8  29.5  77.4  53.7  53.7  14.7
# 3  3          Maine  0.559  0.539     151.7  25.3  73.5  49.9  52.8  16.9
# 4  9       N.J.I.T.  0.495  0.457     137.5  21.9  69.5  45.8  58.0  15.2
# 5  5  New Hampshire  0.501  0.470     149.4  29.8  75.1  51.5  50.6  13.1
# 6  1   UMass Lowell  0.578  0.558     157.8  36.5  72.8  56.4  52.7  18.0
# 7  4           UMBC  0.561  0.531     158.8  27.9  74.5  51.0  55.3  13.4
# 8  6        Vermont  0.539  0.518     146.3  21.2  79.5  49.4  48.9  15.8
#
#    ...  FTA    FT%  ORB  DRB  REB  AST  STL  BLK  TOV   PF
# 0  ...  265  0.683  153  312  465  169   87   30  197  289
# 1  ...  214  0.682  119  279  398  125   54   38  158  200
# ...

# %%
#data for all d1 basketball
df1 = pd.read_csv("AllD1.csv")
df1
# Out:
#          #               Team    TS%   eFG%  Total S%   ORB%   DRB%   TRB%  \
# 0     88.0  Abilene Christian  0.565  0.541    155.50  29.70  74.30  50.80
# 1     92.0          Air Force  0.596  0.570    155.00  24.10  71.80  50.20
# 2    121.0              Akron  0.525  0.500    141.90  31.90  75.60  53.80
# 3     94.0            Alabama  0.554  0.516    149.50  37.50  74.40  56.90
# 4    293.0        Alabama A&M  0.540  0.514    155.30  28.90  63.40  46.30
# ..     ...                ...    ...    ...       ...    ...    ...    ...
# 359  191.0            Wyoming  0.561  0.531    149.70  25.90  77.80  51.10
# 360   86.0             Xavier  0.607  0.583    165.50  30.60  76.20  55.10
# 361    8.0               Yale  0.572  0.554    154.00  34.30  76.80  56.70
# 362   67.0   Youngstown State  0.589  0.557    164.20  34.20  71.10  53.40
# 363    NaN                NaN  0.550  0.520    150.18  30.22  73.34  52.04
#
# ...

# %%
#looking at variables to compare
df.columns
# Out:
# Index(['#', 'Team', 'TS%', 'eFG%', 'Total S%', 'ORB%', 'DRB%', 'TRB%', 'AST%',
#        'TOV%', 'STL%', 'BLK%', 'PPS', 'FIC40', 'ORtg', 'DRtg', 'eDiff', 'Poss',
#        'Pace', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'REB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF'],
#       dtype='object')

# %%
#comparing offense and defense rating for AE
aeRating = df[['Team', 'ORtg', 'DRtg']].copy()
aeRating
# Out:
#             Team   ORtg   DRtg
# 0         Albany   97.8  107.6
# 1     Binghamton   99.7  103.4
# 2         Bryant  111.5   95.0
# 3          Maine  103.7   95.5
# 4       N.J.I.T.   93.5  104.0
# 5  New Hampshire  102.0   96.6
# 6   UMass Lowell  109.9   85.9
# 7           UMBC  110.9  104.0
# 8        Vermont  100.1  102.5

# %%
#comparing offense and defense rating for D1
d1rating = df1[['Team', 'ORtg', 'DRtg']].copy()
d1rating
# Out:
#                   Team    ORtg    DRtg
# 0    Abilene Christian  106.60   92.30
# 1            Air Force  108.10   94.00
# 2                Akron  103.60   92.60
# 3              Alabama  108.10   94.10
# 4          Alabama A&M  100.70  103.80
# ..                 ...     ...     ...
# 359            Wyoming  107.60  101.70
# 360             Xavier  113.50   99.00
# 361               Yale  114.60   86.20
# 362   Youngstown State  115.70   99.90
# 363                NaN  104.98   97.14
#
# [364 rows x 3 columns]

# %%
#finding the d1 average ratings
ratingAVG.mean()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\2458482824.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ratingAVG.mean()
# ORtg    103.806264
# DRtg     97.913860
# dtype: float64

# %%
#creating a new dataframe to plot the average
ratingAVG = pd.DataFrame({'ORtg': [103.806264],
                   'DRtg': [97.91386],
                    'Team' : ['D1 Average']})
ratingAVG
# Out:
#          ORtg      DRtg        Team
# 0  103.806264  97.91386  D1 Average

# %%
#combining the AE ratings with D1 average ratings 
newdf = aeRating.append(ratingAVG)
newdf
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\1926649510.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf = aeRating.append(ratingAVG)
#             Team        ORtg       DRtg
# 0         Albany   97.800000  107.60000
# 1     Binghamton   99.700000  103.40000
# 2         Bryant  111.500000   95.00000
# 3          Maine  103.700000   95.50000
# 4       N.J.I.T.   93.500000  104.00000
# 5  New Hampshire  102.000000   96.60000
# 6   UMass Lowell  109.900000   85.90000
# 7           UMBC  110.900000  104.00000
# 8        Vermont  100.100000  102.50000
# 0     D1 Average  103.806264   97.91386

# %%
#plotting the teams and d1 average using a scatter plot
ax = newdf.plot(x='ORtg',y='DRtg',kind='scatter',figsize=(10,10))
newdf[['ORtg','DRtg','Team']].apply(lambda x: ax.text(*x),axis=1)
plt.xlabel('Offensive Rating')
plt.ylabel('Defensive Rating')
plt.title('America East Offensive vs. Defensive Rating in 2022', fontsize=16)
plt.show()

# %% [markdown]
# Top Left: Great defense, poor offense
# Bottom Left: Poor defense, poor offense
# Top Right: Great defense, great offense
# Bottom Right: Poor defense, great offense

# %%
aePace = df[['Team', 'Poss', 'Pace']].copy()
aePace
# Out:
#             Team    Poss  Pace
# 0         Albany   973.9  69.5
# 1     Binghamton   768.5  69.9
# 2         Bryant   938.4  77.5
# 3          Maine   755.3  68.7
# 4       N.J.I.T.   726.0  66.0
# 5  New Hampshire   739.1  66.4
# 6   UMass Lowell  1027.8  72.8
# 7           UMBC   909.7  70.0
# 8        Vermont   950.1  66.7

# %%
d1pace = df1[['Team', 'Poss', 'Pace']].copy()
d1pace
# Out:
#                   Team    Poss   Pace
# 0    Abilene Christian  848.80  71.00
# 1            Air Force  780.70  64.40
# 2                Akron  736.20  66.20
# 3              Alabama  851.10  74.00
# 4          Alabama A&M  807.60  73.30
# ..                 ...     ...    ...
# 359            Wyoming  753.00  67.70
# 360             Xavier  895.90  74.70
# 361               Yale  802.00  66.20
# 362   Youngstown State  889.20  72.70
# 363                NaN  815.09  69.81
#
# [364 rows x 3 columns]

# %%
d1pace.mean()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\1557089128.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d1pace.mean()
# Poss    810.810412
# Pace     69.769258
# dtype: float64

# %%
paceAVG = pd.DataFrame({'Poss': [810.810412],
                   'Pace': [69.769258],
                    'Team' : ['D1 Average']})
paceAVG
# Out:
#          Poss       Pace        Team
# 0  810.810412  69.769258  D1 Average

# %%
newdf1 = aePace.append(paceAVG)
newdf1
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\169362191.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf1 = aePace.append(paceAVG)
#             Team         Poss       Pace
# 0         Albany   973.900000  69.500000
# 1     Binghamton   768.500000  69.900000
# 2         Bryant   938.400000  77.500000
# 3          Maine   755.300000  68.700000
# 4       N.J.I.T.   726.000000  66.000000
# 5  New Hampshire   739.100000  66.400000
# 6   UMass Lowell  1027.800000  72.800000
# 7           UMBC   909.700000  70.000000
# 8        Vermont   950.100000  66.700000
# 0     D1 Average   810.810412  69.769258

# %%
#plotting the teams and d1 average using a scatter plot
ax = newdf1.plot(x='Pace',y='Poss',kind='scatter',figsize=(10,10))
newdf1[['Pace','Poss','Team']].apply(lambda x: ax.text(*x),axis=1)
#label axis and title
plt.xlabel('Pace')
plt.ylabel('Poss')
plt.title('America East Possesions vs. Pace in 2022', fontsize=16)
plt.show()

# %%
aeShooting = df[['Team', 'TS%', 'eFG%']].copy()
aeShooting
# Out:
#             Team    TS%   eFG%
# 0         Albany  0.514  0.481
# 1     Binghamton  0.524  0.493
# 2         Bryant  0.575  0.544
# 3          Maine  0.559  0.539
# 4       N.J.I.T.  0.495  0.457
# 5  New Hampshire  0.501  0.470
# 6   UMass Lowell  0.578  0.558
# 7           UMBC  0.561  0.531
# 8        Vermont  0.539  0.518

# %%
d1Shooting = df1[['Team', 'TS%', 'eFG%']].copy()
d1Shooting
# Out:
#                   Team    TS%   eFG%
# 0    Abilene Christian  0.565  0.541
# 1            Air Force  0.596  0.570
# 2                Akron  0.525  0.500
# 3              Alabama  0.554  0.516
# 4          Alabama A&M  0.540  0.514
# ..                 ...    ...    ...
# 359            Wyoming  0.561  0.531
# 360             Xavier  0.607  0.583
# 361               Yale  0.572  0.554
# 362   Youngstown State  0.589  0.557
# 363                NaN  0.550  0.520
#
# [364 rows x 3 columns]

# %%
d1Shooting.mean()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\892646387.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d1Shooting.mean()
# TS%     0.541745
# eFG%    0.512527
# dtype: float64

# %%
shootingAVG = pd.DataFrame({'TS%': [0.541745],
                   'eFG%': [0.512527],
                    'Team' : ['D1 Average']})
shootingAVG
# Out:
#         TS%      eFG%        Team
# 0  0.541745  0.512527  D1 Average

# %%
newdf2 = aeShooting.append(shootingAVG)
newdf2
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\2847494348.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf2 = aeShooting.append(shootingAVG)
#             Team       TS%      eFG%
# 0         Albany  0.514000  0.481000
# 1     Binghamton  0.524000  0.493000
# 2         Bryant  0.575000  0.544000
# 3          Maine  0.559000  0.539000
# 4       N.J.I.T.  0.495000  0.457000
# 5  New Hampshire  0.501000  0.470000
# 6   UMass Lowell  0.578000  0.558000
# 7           UMBC  0.561000  0.531000
# 8        Vermont  0.539000  0.518000
# 0     D1 Average  0.541745  0.512527

# %%
#plotting the teams and d1 average using a scatter plot
ax = newdf2.plot(x='TS%',y='eFG%',kind='scatter',figsize=(10,10))
newdf2[['TS%','eFG%','Team']].apply(lambda x: ax.text(*x),axis=1)
#label axis and title
plt.xlabel('True Shooting %')
plt.ylabel('Efficency FG %')
plt.title('America East True Shooting % vs. Efficiency FG % in 2022', fontsize=16)
plt.show()

# %%
aeTovAst = df[['Team', 'AST%', 'TOV%']].copy()
aeTovAst
# Out:
#             Team  AST%  TOV%
# 0         Albany  51.2  17.5
# 1     Binghamton  44.8  17.8
# 2         Bryant  53.7  14.7
# 3          Maine  52.8  16.9
# 4       N.J.I.T.  58.0  15.2
# 5  New Hampshire  50.6  13.1
# 6   UMass Lowell  52.7  18.0
# 7           UMBC  55.3  13.4
# 8        Vermont  48.9  15.8

# %%
#comparing offense and defense rating
d1TovAst = df1[['Team', 'AST%', 'TOV%']].copy()
d1TovAst
# Out:
#                   Team   AST%  TOV%
# 0    Abilene Christian  59.20  17.6
# 1            Air Force  67.80  17.7
# 2                Akron  54.30  15.1
# 3              Alabama  54.60  18.3
# 4          Alabama A&M  52.00  17.8
# ..                 ...    ...   ...
# 359            Wyoming  52.50  14.7
# 360             Xavier  68.00  16.6
# 361               Yale  53.10  14.7
# 362   Youngstown State  47.30  15.5
# 363                NaN  52.41  16.1
#
# [364 rows x 3 columns]

# %%
d1TovAst.mean()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\2400774818.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d1TovAst.mean()
# AST%    52.401401
# TOV%    16.301923
# dtype: float64

# %%
TovAstAVG = pd.DataFrame({'TOV%': [16.301923],
                   'AST%': [52.401401],
                    'Team' : ['D1 Average']})
TovAstAVG
# Out:
#         TOV%       AST%        Team
# 0  16.301923  52.401401  D1 Average

# %%
newdf3 = aeTovAst.append(TovAstAVG)
newdf3
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\2359699225.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf3 = aeTovAst.append(TovAstAVG)
#             Team       AST%       TOV%
# 0         Albany  51.200000  17.500000
# 1     Binghamton  44.800000  17.800000
# 2         Bryant  53.700000  14.700000
# 3          Maine  52.800000  16.900000
# 4       N.J.I.T.  58.000000  15.200000
# 5  New Hampshire  50.600000  13.100000
# 6   UMass Lowell  52.700000  18.000000
# 7           UMBC  55.300000  13.400000
# 8        Vermont  48.900000  15.800000
# 0     D1 Average  52.401401  16.301923

# %%
#plotting the teams and d1 average using a scatter plot
ax = newdf3.plot(x='AST%',y='TOV%',kind='scatter',figsize=(10,10))
newdf3[['AST%','TOV%','Team']].apply(lambda x: ax.text(*x),axis=1)
#label axis and title
plt.xlabel('Assist %')
plt.ylabel('Turnover %')
plt.title('America East Assist % vs. Turnover % in 2022', fontsize=16)
plt.show()

# %%
aeThree = df[['Team', '3P%', '3PA']].copy()
aeThree
# Out:
#             Team    3P%  3PA
# 0         Albany  0.333  333
# 1     Binghamton  0.297  209
# 2         Bryant  0.364  316
# 3          Maine  0.329  219
# 4       N.J.I.T.  0.310  226
# 5  New Hampshire  0.353  275
# 6   UMass Lowell  0.386  251
# 7           UMBC  0.371  353
# 8        Vermont  0.337  326

# %%
d1Three = df1[['Team', '3P%', '3PA']].copy()
d1Three
# Out:
#                   Team    3P%     3PA
# 0    Abilene Christian  0.379  253.00
# 1            Air Force  0.372  285.00
# 2                Akron  0.335  284.00
# 3              Alabama  0.347  323.00
# 4          Alabama A&M  0.411  224.00
# ..                 ...    ...     ...
# 359            Wyoming  0.344  311.00
# 360             Xavier  0.423  227.00
# 361               Yale  0.345  287.00
# 362   Youngstown State  0.382  259.00
# 363                NaN  0.340  256.91
#
# [364 rows x 3 columns]

# %%
d1Three.mean()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\2966699050.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d1Three.mean()
# 3P%      0.341374
# 3PA    256.466786
# dtype: float64

# %%
threeAVG = pd.DataFrame({'3P%': [0.341374],
                   '3PA': [256.466786],
                    'Team' : ['D1 Average']})
threeAVG
# Out:
#         3P%         3PA        Team
# 0  0.341374  256.466786  D1 Average

# %%
newdf4 = aeThree.append(threeAVG)
newdf4
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\1836831855.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf4 = aeThree.append(threeAVG)
#             Team       3P%         3PA
# 0         Albany  0.333000  333.000000
# 1     Binghamton  0.297000  209.000000
# 2         Bryant  0.364000  316.000000
# 3          Maine  0.329000  219.000000
# 4       N.J.I.T.  0.310000  226.000000
# 5  New Hampshire  0.353000  275.000000
# 6   UMass Lowell  0.386000  251.000000
# 7           UMBC  0.371000  353.000000
# 8        Vermont  0.337000  326.000000
# 0     D1 Average  0.341374  256.466786

# %%
#plotting the teams and d1 average using a scatter plot
ax = newdf4.plot(x='3P%',y='3PA',kind='scatter',figsize=(10,10))
newdf4[['3P%','3PA','Team']].apply(lambda x: ax.text(*x),axis=1)
#label axis and title
plt.xlabel('3P%')
plt.ylabel('3PA')
plt.title('America East 3-Point Attempts vs. 3-Point % in 2022', fontsize=16)
plt.show()

# %%
aeFTrebound = df[['Team', 'FT%', 'TRB%']].copy()
aeFTrebound
# Out:
#             Team    FT%  TRB%
# 0         Albany  0.683  49.2
# 1     Binghamton  0.682  51.7
# 2         Bryant  0.734  53.7
# 3          Maine  0.706  49.9
# 4       N.J.I.T.  0.668  45.8
# 5  New Hampshire  0.744  51.5
# 6   UMass Lowell  0.690  56.4
# 7           UMBC  0.767  51.0
# 8        Vermont  0.678  49.4

# %%
d1FTrebound = df1[['Team', 'FT%', 'TRB%']].copy()
d1FTrebound
# Out:
#                   Team    FT%   TRB%
# 0    Abilene Christian  0.703  50.80
# 1            Air Force  0.697  50.20
# 2                Akron  0.660  53.80
# 3              Alabama  0.713  56.90
# 4          Alabama A&M  0.697  46.30
# ..                 ...    ...    ...
# 359            Wyoming  0.709  51.10
# 360             Xavier  0.717  55.10
# 361               Yale  0.709  56.70
# 362   Youngstown State  0.767  53.40
# 363                NaN  0.710  52.04
#
# [364 rows x 3 columns]

# %%
d1FTrebound.mean()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\3649927363.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d1FTrebound.mean()
# FT%      0.703102
# TRB%    51.411648
# dtype: float64

# %%
ftReboundAVG = pd.DataFrame({'FT%': [0.703102],
                   'TRB%': [51.411648],
                    'Team' : ['D1 Average']})
ftReboundAVG
# Out:
#         FT%       TRB%        Team
# 0  0.703102  51.411648  D1 Average

# %%
newdf5 = aeFTrebound.append(ftReboundAVG)
newdf5
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_19548\2475117174.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf5 = aeFTrebound.append(ftReboundAVG)
#             Team       FT%       TRB%
# 0         Albany  0.683000  49.200000
# 1     Binghamton  0.682000  51.700000
# 2         Bryant  0.734000  53.700000
# 3          Maine  0.706000  49.900000
# 4       N.J.I.T.  0.668000  45.800000
# 5  New Hampshire  0.744000  51.500000
# 6   UMass Lowell  0.690000  56.400000
# 7           UMBC  0.767000  51.000000
# 8        Vermont  0.678000  49.400000
# 0     D1 Average  0.703102  51.411648

# %%
#plotting the teams and d1 average using a scatter plot
ax = newdf5.plot(x='TRB%',y='FT%',kind='scatter',figsize=(10,10))
newdf5[['TRB%','FT%','Team']].apply(lambda x: ax.text(*x),axis=1)
#label axis and title
plt.xlabel('TRB%')
plt.ylabel('FT%')
plt.title('America East Free Throw % vs. Total Rebound % in 2022', fontsize=16)
plt.show()
